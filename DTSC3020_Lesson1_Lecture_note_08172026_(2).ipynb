# %% [markdown]
# <a href="https://colab.research.google.com/github/mehri-satari/MehriSattari_DTSC3020_Summer2026/blob/main/DTSC3020_Lesson1_Lecture_note_08172026_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon h1 { color: #0b6b3a; border-bottom: 2px solid #dcefe5; padding-bottom: 6px; }
# .jp-RenderedHTMLCommon h2 { color: #0e5f43; margin-top: 28px; }
# .jp-RenderedHTMLCommon h3 { color: #205b85; }
# .callout { border-left: 7px solid #0b6b3a; background: #f3fbf5; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .warning { border-left: 7px solid #b45309; background: #fff8e6; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .activity { border-left: 7px solid #2563eb; background: #f2f6ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .checkpoint { border-left: 7px solid #7c3aed; background: #f8f5ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .quiz { border: 1px solid #d8e2ea; background: #fbfdff; padding: 14px 18px; margin: 16px 0; border-radius: 10px; }
# .figcap { font-size: 0.9em; color: #52616b; margin-top: 6px; }
# .figure { margin: 18px 0 24px 0; padding: 8px; background: #ffffff; border: 1px solid #d8e2ea; border-radius: 14px; }
# .small { font-size: 0.92em; color: #52616b; }
# </style>
#
# # DTSC 3020: Introduction to Computation with Python
# ## Lesson 1: Orientation, Introduction, and Setup
#
# **Instructor:** Dr. Haihua Chen
# **Department of Data Science, University of North Texas**
#
# <div class="callout">
# <b>Big idea:</b> Python is a practical language for data science, artificial intelligence, automation, and research. In the era of Generative AI, Python fundamentals help students verify, adapt, debug, and responsibly use AI-generated code.
# </div>

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Lesson 1 Learning Journey" width="950"/></div>

# %% [markdown]
# ## Lesson 1 Learning Objectives
#
# By the end of this lesson, you should be able to:
#
# 1. Explain what Python is and why it is widely used.
# 2. Describe Python's key features, advantages, and limitations.
# 3. Connect Python to real-world uses in data science, AI, automation, and research.
# 4. Understand basic Python architecture: source code, parser, compiler, bytecode, and interpreter.
# 5. Identify beginner-friendly development environments.
# 6. Write and run simple Python code.
# 7. Use comments, indentation, statements, and readable style.
# 8. Explain why Python fundamentals still matter when Generative AI can generate code.

# %% [markdown]
# # Part 1. Course Orientation
#
# DTSC 3020 is not just about memorizing syntax. It is about building a **problem-solving mindset** with Python.
#
# By the end of the course, you should be able to:
#
# - Write Python programs from scratch
# - Read and explain Python code
# - Debug common errors
# - Use variables, data types, loops, functions, and data structures
# - Work with files and simple datasets
# - Complete mini projects
# - Use GitHub to submit programming work
# - Use AI coding tools responsibly and critically
#
# <div class="warning">
# <b>Programming reality:</b> Every programmer sees errors. Errors are feedback, not failure.
# </div>

# %% [markdown]
# # Part 2. What Is Python?
#
# Python is a **general-purpose, object-oriented, dynamically typed, interpreted programming language**.
#
# **Reading:** [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)
#
# | Term | Student-friendly meaning |
# |---|---|
# | General-purpose | Python can be used for many tasks, from small scripts to AI systems. |
# | Object-oriented | Python can model real-world entities using classes and objects. |
# | Dynamically typed | You do not need to declare a variable type before using it. |
# | Interpreted | Python code can be executed through an interpreter. |
# | High-level | Python syntax is closer to human language than machine code. |
#
# Python was named after **Monty Python**, not the snake.

# %%
print("Hello DTSC 3020!")
print("Welcome to Python programming.")
# Out:
# Hello DTSC 3020!
# Welcome to Python programming.

# %% [markdown]
# ## Python as a Calculator
#
# Python can be used interactively, almost like a calculator. Try running and modifying the following cell.

# %%
# Python as a calculator
print(10 + 5)
print(10 - 5)
print(10 * 5)
print(10 / 5)
print(2 ** 3)   # exponentiation: 2 to the power of 3
# Out:
# 15
# 5
# 50
# 2.0
# 8

# %% [markdown]
# # Part 3. A Brief History of Python
#
# Python was conceived in the late 1980s. Guido van Rossum began implementing it in December 1989. Python 2.0 was released in 2000, and Python 3.0 was released in 2008.
#
# **Reading:** [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Brief History of Python" width="950"/><p class="figcap">Timeline recreated from DataFlair's Python history discussion.</p></div>

# %% [markdown]
# # Part 4. Python Features
#
# Features that make Python popular: easy syntax, interpreted execution, object-oriented programming, free and open-source access, portability, GUI support, large libraries, and dynamic typing.
#
# **Readings:**
# - [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)
# - [Python Features — DataFlair](https://data-flair.training/blogs/features-of-python/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Major Features of Python" width="950"/></div>

# %% [markdown]
# ## Why Features Matter to Beginners
#
# Python's features are not just abstract ideas. They affect how you learn:
#
# - **Easy syntax** helps beginners focus on logic.
# - **Interpreted execution** makes experimentation faster.
# - **Large libraries** allow you to build useful projects sooner.
# - **Portability** means your code can run on different computers.
# - **Dynamic typing** reduces early syntax burden, but still requires careful testing.

# %%
# Dynamic typing example
value = 10
print(value, type(value))

value = "Python"
print(value, type(value))

value = 3.14
print(value, type(value))

# %% [markdown]
# <div class="checkpoint">
# <b>Checkpoint:</b> What happened to <code>value</code> in the previous cell? Why might dynamic typing be helpful for beginners but risky in larger programs?
# </div>

# %% [markdown]
# <b>Answer:</b> [In what ways are dynamically typed languages more productive?](https://allanderek.github.io/posts/dynamically-typed-languages-why/)

# %% [markdown]
# # Part 5. What Can We Do with Python?
#
# Possible Python applications, including web development, game development, computer vision, machine learning, robotics, web scraping, data analysis, automation, scripting, scientific computing, artificial intelligence, audio/video applications, and computer-aided design.
#
# **Reading:** [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Python Applications" width="950"/></div>

# %% [markdown]
# ## Real-World Scenario Examples
#
# | Scenario | Why Python helps |
# |---|---|
# | A data science student wants to analyze survey responses | Python can clean and summarize data. |
# | A business student wants to automate weekly reports | Python can process files and generate outputs. |
# | A health informatics student wants to process text | Python can tokenize, count, and structure text. |
# | A researcher wants to collect public website data | Python can support web scraping. |
# | A student using GenAI wants to verify generated code | Python knowledge helps test and debug the output. |

# %%
# Example: summarize simple survey responses
responses = ["Python", "AI", "Python", "Data Science", "Python", "AI"]

python_count = responses.count("Python")
ai_count = responses.count("AI")

print("Python responses:", python_count)
print("AI responses:", ai_count)
# Out:
# Python responses: 3
# AI responses: 2

# %% [markdown]
# # Part 6. Advantages and Limitations of Python
#
# Python is productive, readable, supported by large libraries, portable, and open source. It also discusses limitations such as slower speed compared with compiled languages, weaker fit for some mobile/browser-side applications, possible runtime errors, and memory concerns.
#
# **Reading:** [Advantages and Disadvantages of Python — DataFlair](https://data-flair.training/blogs/advantages-and-disadvantages-of-python/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Python Advantages and Limitations" width="950"/></div>

# %%
# Python can express ideas concisely
scores = [88, 92, 79, 95, 100]
average_score = sum(scores) / len(scores)
highest_score = max(scores)
lowest_score = min(scores)

print("Average:", average_score)
print("Highest:", highest_score)
print("Lowest:", lowest_score)

# %% [markdown]
# # Part 7. Python in the Era of Generative AI
#
# Generative AI can write code, but students still need programming knowledge because AI-generated code must be:
#
# - Understood
# - Tested
# - Debugged
# - Adapted
# - Documented
# - Evaluated for correctness
#
# Python fundamentals help you become a better user of AI tools, not just a passive consumer of generated answers.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Human + GenAI + Python Workflow" width="950"/><p class="figcap">Instructor-created workflow for responsible AI-assisted programming.</p></div>

# %% [markdown]
# ## GenAI-Era Example 1: Verify an AI Claim
#
# Suppose an AI tool says:
#
# > If a student studies 7 hours per week for 8 weeks, the total is 54 hours.
#
# Use Python to verify this.

# %%
hours_per_week = 7
weeks = 8

total_hours = hours_per_week * weeks

print("Correct total hours:", total_hours)

# %% [markdown]
# ## GenAI-Era Example 2: Detect a Logic Bug
#
# A GenAI tool may generate code that works for normal cases but fails for edge cases.
#
# The following code calculates an average.

# %%
scores = [90, 80, 100]
average = sum(scores) / len(scores)
print("Average:", average)

# %% [markdown]
# Now try an empty list. This is an **edge case**.

# %%
scores = []

if len(scores) == 0:
    print("No scores available. Cannot calculate average.")
else:
    average = sum(scores) / len(scores)
    print("Average:", average)

# %% [markdown]
# ## GenAI-Era Example 3: Check Whether a Response Meets Requirements
#
# Suppose you ask an AI tool to write a short course description that must mention Python, data science, and AI. Python can check whether required terms appear.

# %%
ai_generated_text = '''
This course introduces Python programming for data science, automation, and AI applications.
Students will learn to write, test, and improve code.
'''

required_terms = ["Python", "data science", "AI"]

for term in required_terms:
    appears = term.lower() in ai_generated_text.lower()
    print(f"{term}: {appears}")

# %% [markdown]
# ## GenAI-Era Example 4: Clean Messy Text
#
# AI-generated or human-written text often contains inconsistent spacing and capitalization. Python can clean it.

# %%
raw_topics = [" python ", "PYTHON", "Data Science ", " data science", "AI", " ai "]

cleaned_topics = []

for topic in raw_topics:
    cleaned_topics.append(topic.strip().lower())

print(cleaned_topics)

# %% [markdown]
# # Part 8. Python Architecture and Working
#
# Python's architecture using the ideas of source code, parser, compiler, bytecode, and interpreter.
#
# **Reading:** [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Python Execution Architecture" width="950"/><p class="figcap">Recreated from DataFlair's parser → compiler → interpreter explanation.</p></div>

# %% [markdown]
# ## Practical Meaning for Beginners
#
# You do not need to master compiler theory in this class. But you should understand this:
#
# 1. You write source code.
# 2. Python checks whether the code follows syntax rules.
# 3. Python turns it into a form it can run.
# 4. The interpreter executes the code.
# 5. You inspect the output and fix errors.

# %% [markdown]
# # Part 9. Python Constructs: Preview of the Course
#
# Several important Python constructs: functions, classes, modules, and packages.
#
# **Reading:** [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)
#
# | Construct | Beginner meaning | Course connection |
# |---|---|---|
# | Function | A named group of statements that performs a task | Later lesson |
# | Class | A blueprint for creating objects | Later lesson |
# | Module | A file or unit containing related functions/classes | Later lesson |
# | Package | A collection of related modules | Later projects |

# %% [markdown]
# ## Preview: Function

# %%
def greet_student(name):
    print("Welcome to DTSC 3020,", name)

greet_student("Alice")

# %% [markdown]
# ## Preview: Class

# %%
class Student:
    def __init__(self, name, major):
        self.name = name
        self.major = major

    def introduce(self):
        print(f"My name is {self.name}, and my major is {self.major}.")

student = Student("Alice", "Data Science")
student.introduce()

# %% [markdown]
# ## Preview: Module

# %%
import math

print("Square root of 16:", math.sqrt(16))
print("Value of pi:", math.pi)

# %% [markdown]
# # Part 10. Installing Python and Choosing an IDE
#
# **Reading:** [Installing Python and IDEs — RKSTechAcademy](https://rkstechademy.odoo.com/slides/slide/1-2-1-installing-python-and-ides-e-g-pycharm-vscode-jupyter-70)
#
# | Tool | Best for | Recommended for |
# |---|---|---|
# | Google Colab | Browser-based coding with no installation | Beginners |
# | Jupyter Notebook | Interactive learning and data work | Beginners |
# | VS Code | Scripts, projects, GitHub workflows | Intermediate |
# | PyCharm | Larger software projects | Intermediate |
# | Terminal | Running `.py` files directly | Everyone eventually |
#
# For the first week, Google Colab or Jupyter Notebook is enough.

# %% [markdown]
# # Part 11. Syntax, Comments, Indentation, and Statements
#
# **Readings:**
# - [Python Syntax and Semantics — DataFlair](https://data-flair.training/blogs/python-syntax-semantics/)
# - [Python Comments, Indentation, and Statements — DataFlair](https://data-flair.training/blogs/python-comment/)
#
# Python syntax is designed to be readable. But it is still strict. Small mistakes such as missing quotation marks or incorrect indentation can cause errors.

# %% [markdown]
# ## Statements

# %%
student_name = "Alice"
course = "DTSC 3020"
print(student_name, "is taking", course)

# %% [markdown]
# ## Comments

# %%
# This program prints basic course information
course_name = "Introduction to Computation with Python"
print(course_name)

# %% [markdown]
# ## Indentation

# %%
temperature = 72

if temperature >= 70:
    print("It is warm.")
    print("This line is inside the if block.")

print("This line is outside the if block.")
# Out:
# It is warm.
# This line is inside the if block.
# This line is outside the if block.

# %% [markdown]
# ## Common Syntax Mistakes
#
# | Mistake | Example | Fix |
# |---|---|---|
# | Missing parentheses | `print "Hello"` | `print("Hello")` |
# | Invalid variable name | `student name = "Alice"` | `student_name = "Alice"` |
# | Missing quote | `"Python` | `"Python"` |
# | Bad indentation | no spaces after `if` | indent the block |

# %% [markdown]
# # Part 12. Running Python Scripts
#
# **Reading:** [Running Python Scripts with uv — Astral Docs](https://docs.astral.sh/uv/guides/scripts/#declaring-script-dependencies)
#
# A Python script usually has the `.py` extension.
#
# Example file:
#
# ```python
# print("Hello DTSC 3020")
# ```
#
# Save it as:
#
# ```text
# hello.py
# ```
#
# Run it from a terminal:
#
# ```bash
# python hello.py
# ```
#
# Modern tools such as `uv` can also run scripts and manage dependencies:
#
# ```bash
# uv run hello.py
# ```

# %% [markdown]
# # Part 13. Best Practices: Start Professional Habits Early
#
# DataFlair's best-practices article discusses version control, documentation, style guidelines, fixing broken code, PyPI, Zen of Python, choosing data structures, readability, virtual environments, and object-oriented code.
#
# **Reading:** [Python Best Practices — DataFlair](https://data-flair.training/blogs/python-best-practices/)

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Professional Project Organization" width="950"/></div>

# %% [markdown]
# ## Beginner-Friendly Best Practices
#
# | Best practice | What it means in this course |
# |---|---|
# | Use clear names | Use `student_score`, not `x`, when possible. |
# | Write comments | Explain non-obvious logic. |
# | Use GitHub | Submit clean repositories with `.py` or `.ipynb` files. |
# | Fix broken code early | Do not build on top of errors. |
# | Use readable formatting | Use spaces, indentation, and clear structure. |
# | Avoid magic numbers | Store important values in named variables. |
# | Test with examples | Do not assume code works after one run. |

# %%
# Less readable
x = 95
y = 100
z = x / y
print(z)

# More readable
assignment_score = 95
maximum_score = 100
percentage = assignment_score / maximum_score
print(percentage)

# %% [markdown]
# ## The Zen of Python
#
# The Zen of Python as a set of values for writing Python code. Run this cell.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Part 14. Interactive Activities
#
# ## Activity 1: Student Introduction Program
#
# Edit the code below to introduce yourself.

# %%
# Activity 1: Student Introduction Program

print("Name: Your Name")
print("Major: Your Major")
print("Career Goal: Your Career Goal")
print("Favorite Technology: Your Favorite Technology")
print("One reason I want to learn Python: Your Reason")
# Out:
# Name: Your Name
# Major: Your Major
# Career Goal: Your Career Goal
# Favorite Technology: Your Favorite Technology
# One reason I want to learn Python: Your Reason

# %% [markdown]
# ## Activity 2: Fix the Broken Code
#
# The code below has common beginner mistakes:
#
# ```python
# print "Hello Python"
# student name = "Alice"
# if True:
# print("Welcome")
# ```
#
# Fix it below before checking the answer.

# %%
# Activity 2: Write your fixed version here

# %% [markdown]
# <details>
# <summary><b>Click to reveal one possible fixed answer</b></summary>
#
# ```python
# print("Hello Python")
#
# student_name = "Alice"
#
# if True:
#     print("Welcome", student_name)
# ```
#
# </details>

# %% [markdown]
# # Part 15. Click-to-Reveal Quiz
#
# Try to answer each question first. Then click to reveal the answer.

# %% [markdown]
# <div class="quiz">
# <p><b>Question 1. Which statement best describes Python?</b></p>
#
# - A. A low-level machine language
# - B. A general-purpose, high-level programming language
# - C. A spreadsheet program
# - D. A database only
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. A general-purpose, high-level programming language
#
# <br><br>
#
# <b>Explanation:</b> Python is widely used across many fields and has readable, high-level syntax.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 2. Why is indentation important in Python?</b></p>
#
# - A. It defines code blocks
# - B. It changes the font
# - C. It installs packages
# - D. It creates websites automatically
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> A. It defines code blocks
#
# <br><br>
#
# <b>Explanation:</b> Python uses indentation to identify which statements belong together, such as inside an if statement or loop.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 3. Why should students learn Python in the GenAI era?</b></p>
#
# - A. To avoid thinking about code
# - B. To blindly trust generated code
# - C. To read, test, debug, and improve AI-generated code
# - D. To make programs longer
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. To read, test, debug, and improve AI-generated code
#
# <br><br>
#
# <b>Explanation:</b> AI can draft code, but students need Python knowledge to judge whether it is correct and appropriate.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 4. Which of the following is a limitation of Python?</b></p>
#
# - A. It has no libraries
# - B. It cannot print text
# - C. It can be slower than compiled languages
# - D. It only works on one operating system
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. It can be slower than compiled languages
#
# <br><br>
#
# <b>Explanation:</b> Because Python is interpreted and high-level, it may run slower than compiled languages such as C or C++ in some cases.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 5. What is the best beginner habit?</b></p>
#
# - A. Use random variable names
# - B. Ignore error messages
# - C. Write readable code and test it
# - D. Submit screenshots instead of code
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. Write readable code and test it
#
# <br><br>
#
# <b>Explanation:</b> Readable code, meaningful names, comments, and testing are strong habits for programming success.
# </details>
# </div>

# %% [markdown]
# ## Activity 3: AI Verification Challenge
#
# A GenAI tool says:
#
# > A student who studies 9 hours per week for 8 weeks studies 70 hours total.
#
# Use Python to verify the statement.

# %%
hours_per_week = 9
weeks = 8

total = hours_per_week * weeks
print("Correct total:", total)

# %% [markdown]
# ## Activity 4: Course Planner
#
# Use Python to print a study checklist.

# %%
lesson_tasks = [
    "Review Lesson 1 notebook",
    "Run all code cells",
    "Complete Activity 1",
    "Set up Google Colab or Jupyter",
    "Prepare for Lesson 2"
]

for task in lesson_tasks:
    print("[ ]", task)

# %% [markdown]
# # Part 16. Exit Ticket
#
# Before the next class, answer these questions:
#
# 1. What is Python?
# 2. What are three applications of Python?
# 3. What is one advantage and one limitation of Python?
# 4. Why does indentation matter?
# 5. What is one way Python helps you use GenAI responsibly?
# 6. Which coding environment will you use first?

# %% [markdown]
# # Lesson 1 Summary
#
# Today we covered:
#
# - Course orientation
# - What Python is
# - Python history
# - Python features
# - Python applications
# - Python advantages and limitations
# - Python in the era of Generative AI
# - Python architecture and working
# - Functions, classes, modules, and packages preview
# - Setup options
# - Syntax, comments, indentation, and statements
# - Running scripts
# - Best practices
# - Interactive beginner exercises

# %% [markdown]
# # Complete Source List and Credits
#
# ## Assigned Lesson 1 Sources
#
# 1. [Introduction to Python — DataFlair](https://data-flair.training/blogs/python-introduction/)
# 2. [Python Features — DataFlair](https://data-flair.training/blogs/features-of-python/)
# 3. [Advantages and Disadvantages of Python — DataFlair](https://data-flair.training/blogs/advantages-and-disadvantages-of-python/)
# 4. [Python Master Guide — DataFlair](https://data-flair.training/blogs/learn-python-notes/)
# 5. [Python Best Practices — DataFlair](https://data-flair.training/blogs/python-best-practices/)
# 6. [Why Learn Python — DataFlair](https://data-flair.training/blogs/why-learn-python/)
# 7. [Installing Python and IDEs — RKSTechAcademy](https://rkstechademy.odoo.com/slides/slide/1-2-1-installing-python-and-ides-e-g-pycharm-vscode-jupyter-70)
# 8. [Python Syntax and Semantics — DataFlair](https://data-flair.training/blogs/python-syntax-semantics/)
# 9. [Running Python Scripts with uv — Astral Docs](https://docs.astral.sh/uv/guides/scripts/#declaring-script-dependencies)
# 10. [Python Comments, Indentation, and Statements — DataFlair](https://data-flair.training/blogs/python-comment/)
#
# ## Diagram Credits
#
# The diagrams in this notebook are recreated as embedded high-resolution PNG figures so they display correctly offline. They are based on, adapted from, or inspired by the assigned readings above:
#
# - Lesson learning journey: instructor-created based on DTSC 3020 course flow.
# - Python history: recreated from DataFlair's Python introduction.
# - Python features: recreated from DataFlair's Python introduction and features readings.
# - Python applications: summarized from DataFlair's Python introduction.
# - Python advantages and limitations: adapted from DataFlair's pros and cons article.
# - Python architecture: recreated from DataFlair's parser, compiler, and interpreter explanation.
# - Project organization: inspired by DataFlair's best-practices discussion of repositories, README files, documentation, tests, and requirements.
# - Human + GenAI + Python workflow: instructor-created for DTSC 3020.
